# %%
import rdflib
import requests
from bs4 import BeautifulSoup

# %%
base_url = "https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/conductivity.trig"

# %%
response = requests.get(base_url)
if response.status_code == 200:
    g = rdflib.Graph()
    g.parse(data=response.text, format="trig")

    # Extract all triples
    triples = list(g)

    # Print the extracted triples
    # for s, p, o in triples:
    #     print(f"Subject: {s}, Predicate: {p}, Object: {o}")
# Out:
# Subject: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/conductivity#eventstream, Predicate: https://w3id.org/tree#view, Object: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/conductivity.trig
# Subject: n4aa0de01ae56419f920db75c19ff309bb5, Predicate: https://w3id.org/tree#path, Object: https://w3id.org/tss#from
# Subject: n4aa0de01ae56419f920db75c19ff309bb1, Predicate: https://w3id.org/tree#value, Object: 2026-01-01T00:00:00+00:00
# Subject: n4aa0de01ae56419f920db75c19ff309bb7, Predicate: https://w3id.org/tree#node, Object: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/2026/2026.trig
# Subject: n4aa0de01ae56419f920db75c19ff309bb10, Predicate: https://w3id.org/tree#path, Object: https://w3id.org/tss#from
# Subject: n4aa0de01ae56419f920db75c19ff309bb8, Predicate: https://w3id.org/tree#path, Object: https://w3id.org/tss#from
# Subject: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/conductivity.trig, Predicate: https://w3id.org/tree#relation, Object: n4aa0de01ae56419f920db75c19ff309bb7
# Subject: n4aa0de01ae56419f920db75c19ff309bb3, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: https://w3id.org/tree#GreaterThanOrEqualToRelation
# Subject: n4aa0de01ae56419f920db75c19ff309bb9, Predicate: https://w3id.org/tree#value, Object: 2021-01-01T00:00:00+00:00
# Subject: n4aa0de01ae56419f920db75c19ff309bb9, Predicate: https://w3id.org/tree#node, Object: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/2021/2021.trig
# Subject: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/conductivity.trig, Predicate: https://w3id.org/tree#relation, Object: n4aa0de01ae56419f920db75c19ff309bb5
# Subject: n4aa0de01ae56419f920db75c19ff309bb2, Predicate: https://w3id.org/tree#value, Object: 2022-01-01T00:00:00+00:00
# Subject: n4aa0de01ae56419f920db75c19ff309bb4, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: https://w3id.org/tree#GreaterThanOrEqualToRelation
# Subject: n4aa0de01ae56419f920db75c19ff309bb1, Predicate: https://w3id.org/tree#path, Object: https://w3id.org/tss#from
# Subject: n4aa0de01ae56419f920db75c19ff309bb7, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: https://w3id.org/tree#GreaterThanOrEqualToRelation
# Subject: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/conductivity#eventstream, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: https://w3id.org/ldes#EventStream
# Subject: n4aa0de01ae56419f920db75c19ff309bb6, Predicate: https://w3id.org/tree#node, Object: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/2026/2026.trig
# Subject: n4aa0de01ae56419f920db75c19ff309bb12, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: https://w3id.org/tree#LessThanRelation
# Subject: n4aa0de01ae56419f920db75c19ff309bb2, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: https://w3id.org/tree#LessThanRelation
# Subject: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/conductivity.trig, Predicate: https://w3id.org/tree#relation, Object: n4aa0de01ae56419f920db75c19ff309bb11
# Subject: n4aa0de01ae56419f920db75c19ff309bb9, Predicate: https://w3id.org/tree#path, Object: https://w3id.org/tss#from
# Subject: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/conductivity.trig, Predicate: https://w3id.org/tree#relation, Object: n4aa0de01ae56419f920db75c19ff309bb4
# Subject: n4aa0de01ae56419f920db75c19ff309bb11, Predicate: https://w3id.org/tree#node, Object: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/2023/2023.trig
# Subject: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/conductivity.trig, Predicate: https://w3id.org/tree#relation, Object: n4aa0de01ae56419f920db75c19ff309bb3
# Subject: n4aa0de01ae56419f920db75c19ff309bb6, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: https://w3id.org/tree#LessThanRelation
# Subject: n4aa0de01ae56419f920db75c19ff309bb10, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: https://w3id.org/tree#LessThanRelation
# Subject: n4aa0de01ae56419f920db75c19ff309bb4, Predicate: https://w3id.org/tree#node, Object: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/2024/2024.trig
# Subject: n4aa0de01ae56419f920db75c19ff309bb8, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: https://w3id.org/tree#LessThanRelation
# Subject: n4aa0de01ae56419f920db75c19ff309bb11, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: https://w3id.org/tree#GreaterThanOrEqualToRelation
# Subject: n4aa0de01ae56419f920db75c19ff309bb6, Predicate: https://w3id.org/tree#value, Object: 2027-01-01T00:00:00+00:00
# Subject: n4aa0de01ae56419f920db75c19ff309bb10, Predicate: https://w3id.org/tree#node, Object: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/2023/2023.trig
# Subject: n4aa0de01ae56419f920db75c19ff309bb8, Predicate: https://w3id.org/tree#value, Object: 2025-01-01T00:00:00+00:00
# Subject: n4aa0de01ae56419f920db75c19ff309bb5, Predicate: https://w3id.org/tree#value, Object: 2025-01-01T00:00:00+00:00
# Subject: n4aa0de01ae56419f920db75c19ff309bb4, Predicate: https://w3id.org/tree#value, Object: 2024-01-01T00:00:00+00:00
# Subject: n4aa0de01ae56419f920db75c19ff309bb3, Predicate: https://w3id.org/tree#node, Object: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/2022/2022.trig
# Subject: n4aa0de01ae56419f920db75c19ff309bb7, Predicate: https://w3id.org/tree#value, Object: 2026-01-01T00:00:00+00:00
# Subject: n4aa0de01ae56419f920db75c19ff309bb5, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: https://w3id.org/tree#GreaterThanOrEqualToRelation
# Subject: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/conductivity.trig, Predicate: https://w3id.org/tree#relation, Object: n4aa0de01ae56419f920db75c19ff309bb2
# Subject: n4aa0de01ae56419f920db75c19ff309bb1, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: https://w3id.org/tree#LessThanRelation
# Subject: n4aa0de01ae56419f920db75c19ff309bb12, Predicate: https://w3id.org/tree#value, Object: 2023-01-01T00:00:00+00:00
# Subject: n4aa0de01ae56419f920db75c19ff309bb3, Predicate: https://w3id.org/tree#path, Object: https://w3id.org/tss#from
# Subject: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/conductivity#eventstream, Predicate: https://w3id.org/ldes#timestampPath, Object: https://w3id.org/tss#from
# Subject: n4aa0de01ae56419f920db75c19ff309bb2, Predicate: https://w3id.org/tree#node, Object: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/2021/2021.trig
# Subject: n4aa0de01ae56419f920db75c19ff309bb5, Predicate: https://w3id.org/tree#node, Object: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/2025/2025.trig
# Subject: n4aa0de01ae56419f920db75c19ff309bb7, Predicate: https://w3id.org/tree#path, Object: https://w3id.org/tss#from
# Subject: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/conductivity.trig, Predicate: https://w3id.org/tree#relation, Object: n4aa0de01ae56419f920db75c19ff309bb10
# Subject: n4aa0de01ae56419f920db75c19ff309bb4, Predicate: https://w3id.org/tree#path, Object: https://w3id.org/tss#from
# Subject: n4aa0de01ae56419f920db75c19ff309bb10, Predicate: https://w3id.org/tree#value, Object: 2024-01-01T00:00:00+00:00
# Subject: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/conductivity.trig, Predicate: https://w3id.org/tree#relation, Object: n4aa0de01ae56419f920db75c19ff309bb6
# Subject: n4aa0de01ae56419f920db75c19ff309bb8, Predicate: https://w3id.org/tree#node, Object: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/2024/2024.trig
# Subject: n4aa0de01ae56419f920db75c19ff309bb11, Predicate: https://w3id.org/tree#value, Object: 2023-01-01T00:00:00+00:00
# Subject: n4aa0de01ae56419f920db75c19ff309bb9, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: https://w3id.org/tree#GreaterThanOrEqualToRelation
# Subject: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/conductivity.trig, Predicate: https://w3id.org/tree#relation, Object: n4aa0de01ae56419f920db75c19ff309bb1
# Subject: n4aa0de01ae56419f920db75c19ff309bb1, Predicate: https://w3id.org/tree#node, Object: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/2025/2025.trig
# Subject: n4aa0de01ae56419f920db75c19ff309bb12, Predicate: https://w3id.org/tree#path, Object: https://w3id.org/tss#from
# Subject: n4aa0de01ae56419f920db75c19ff309bb3, Predicate: https://w3id.org/tree#value, Object: 2022-01-01T00:00:00+00:00
# Subject: n4aa0de01ae56419f920db75c19ff309bb6, Predicate: https://w3id.org/tree#path, Object: https://w3id.org/tss#from
# Subject: n4aa0de01ae56419f920db75c19ff309bb2, Predicate: https://w3id.org/tree#path, Object: https://w3id.org/tss#from
# Subject: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/conductivity.trig, Predicate: https://w3id.org/tree#relation, Object: n4aa0de01ae56419f920db75c19ff309bb9
# Subject: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/conductivity.trig, Predicate: https://w3id.org/tree#relation, Object: n4aa0de01ae56419f920db75c19ff309bb8
# Subject: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/conductivity.trig, Predicate: https://w3id.org/tree#relation, Object: n4aa0de01ae56419f920db75c19ff309bb12
# Subject: n4aa0de01ae56419f920db75c19ff309bb11, Predicate: https://w3id.org/tree#path, Object: https://w3id.org/tss#from
# Subject: n4aa0de01ae56419f920db75c19ff309bb12, Predicate: https://w3id.org/tree#node, Object: https://shehabeldeenayman.github.io/Gent-Terneuzen-canal/conductivity/2022/2022.trig
